# %% [markdown]
# Name: Aiden Heath-London

# %% [markdown]
# Lab partner(s): None

# %%
# Import statements go here
# This lab is mainly about Linux/HPC file transfer, so no major Python imports are required.
import os

# %% [markdown]
# # Class 11.2

# %% [markdown]
# Today we are going to be learning how to move files to the supercomputer and back again. Also, I am giving you an extra lab period to finish the statistics module in Datacamp. I figure we could all use some time back this week.
#
# You should also update your final project timeline and submit this with your weekly assessment, see below.

# %% [markdown]
# # Warmups 11.2

# %% [markdown]
# **W.1** Open a terminal window and ssh into the LSU mike supercomputer. Open a second terminal window that we will use to find the path to where you downloaded this file.

# %% [markdown]
# **W.2** Open the ondemand portal and start a jupyter session on the LSU mike supercomputer that lasts 3 hours.

# %% [markdown]
# # Lecture 11.2
#
# ### Agenda:
# - Questions
# - Moving files to the HPC

# %% [markdown]
# ### 11.2.1 Questions

# %% [markdown]
# ### 11.2.1 Questions
#
# Questions I had while working through this lab:
#
# 1. Why does `scp` need to be run from the machine where the source file currently exists?
# 2. How do I know whether the file path I am using is on my local computer or on the LSU HPC?
# 3. What is the difference between copying one file with `scp` and syncing folders with `rsync`?

# %% [markdown]
# ### 11.2.2 Moving files to the HPC

# %% [markdown]
# When working with supercomputers, one often has to move files from a local computer to a supercomputer and back, or from one supercomputer to another. There are a few ways to do this, but the most basic and standard is at the command line using the linux utilities **scp** and **rsync**.
#
# Basically, **scp** stands for "secure copy" and lets you move files or folders from one machine to another. This is the most basic way to move files, and is great for a small amount of data. The second utility, **rsync**, synchronizes entire folders, so you only copy files that have changed, and it can compress files for transfer. Thus, **rsync** is good for moving larger amounts of files or bigger files. Today we will move one file (this lab) from your local computer to the LSU HPC so you can work on your lab there, then move it back.
#
# The basic **scp** syntax is:
#
# **scp**   path_to_local_file   user@host:path_to_destination
#
# or
#
# **scp** source target
#
# So, to use **scp** you need to know the file path where your file currently is and the path to where you want it to go.
#
# For this exercise, you will want to use the two terminal windows opened in the warmup, on where you have logged on to the HPC, and one on your local computer. Locate the folder where you downloaded the lab using the basic linux commands **cd** for change directory, **ls** for listing the directory contents, and **pwd** for printing the "working" directory, the path to where you are. I will demo these.
#
# Use the above linux commands to identify the path to where you have downloaded this lab, and where you want to put it on the supercomputer. Then use **scp** to copy the lab to the super computer. For me this was:
#
# scp /Users/chsharri/Documents/Teaching/Sci_comp/Sci_comp_F2024/Course_materials/Lab11.2_F24_linear_regression.ipynb chsharri@mike.hpc.lsu.edu:/home/chsharri/
#
# Note I put the "/" on the end of the target path to indicate the directory. This will copy the full name of the python notebook into that directory.
#
# I entered this command in the terminal window on my **local** computer. Note you will be asked for your lsu hpc password.
#
# Once you get the lab moved over to the hpc, open it in your hpc jupyter session. You will submit a screenshot of the open lab on mike when you turn in your lab.

# %% [markdown]
# ### 11.2.2 Moving files to the HPC — command notes
#
# Useful Linux commands:
#
# ```bash
# pwd     # shows the current working directory
# ls      # lists files/folders in the current directory
# cd      # changes directories
# ```
#
# Example command to copy this lab from a local computer to LSU Mike HPC:
#
# ```bash
# scp /path/to/Lab11.2_F24_linux.ipynb your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/
# ```
#
# In this command:
#
# - The first path is the **source** file on the local computer.
# - The second path is the **destination** on the HPC.
# - `your_lsu_username@mike.hpc.lsu.edu` tells `scp` which remote system to connect to.

# %% [markdown]
# # Lab 11.2

# %% [markdown]
# Note: You need to submit a screenshot of this lab opened in the LSU HPC in Moodle. You should do E.1 while you have it open there.

# %% [markdown]
# **E.1** Why doesn't the scp command we used to move the lab work in the terminal window where you logged into the LSU hpc? What would you need to do to make that work?

# %% [markdown]
# **Answer to E.1**
#
# The `scp` command used to move the lab to the LSU HPC does not work from the terminal window where I am already logged into the HPC because the source file is on my **local computer**, not on the HPC. When I am logged into the HPC, that terminal is looking at files on the remote HPC system, so it cannot automatically see the files stored on my local Downloads or Documents folder.
#
# To make it work from the HPC terminal, I would need to reverse the direction and copy the file from my local computer to the HPC using a path that the HPC can access. In most cases, the easier method is to run `scp` from my **local computer terminal**, because that terminal can see the local file path and can send the file to:
#
# ```bash
# your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/
# ```
#
# So the main idea is: run the command from the computer that can access the source file, or make sure the source path is valid from the machine where the command is being executed.

# %% [markdown]
# **E.2** Answer E.1 while you are logged to the HPC. Then, transfer the updated lab back to your local computer. How do you have to change the **scp** command to do this?

# %% [markdown]
# **Answer to E.2**
#
# To transfer the updated lab back from the LSU HPC to my local computer, I have to reverse the source and destination in the `scp` command.
#
# When moving the file **to the HPC**, the general form is:
#
# ```bash
# scp local_file your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/
# ```
#
# When moving the file **back to my local computer**, the general form is:
#
# ```bash
# scp your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/Lab11.2_F24_linux.ipynb /path/to/local/folder/
# ```
#
# Example:
#
# ```bash
# scp your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/Lab11.2_F24_linux.ipynb ~/Downloads/
# ```
#
# The change is that the HPC file path becomes the **source**, and the local folder becomes the **destination**.

# %% [markdown]
# **E.3** Complete Ch 3-4 of Introduction to Statistics in Python in Data Camp. Remember to upload your scores into Moodle. For lab 11.1 you should turn in Ch 1-2 scores.

# %% [markdown]
# **E.3 DataCamp completion note**
#
# I will complete Chapters 3–4 of *Introduction to Statistics in Python* in DataCamp and upload my score screenshots into Moodle.
#
# Reminder:
# - Lab 11.1: upload Chapter 1–2 scores.
# - Lab 11.2: upload Chapter 3–4 scores.

# %% [markdown]
# **E.4** Revisit your final project timeline and adjust it based on any changes that came up. You will submit this revised timeline with your Weekly Assesment. Note the updated weekly assessement final project form (in Moodle and github)

# %% [markdown]
# **Notes** Make notes for yourself on progamming tecniques and commands you learned in the this week, including examples, comments and explainitory text. You can do this here or in a separate notebook that you link to here. Basically, you are making a cheat sheet for yourself.

# %% [markdown]
# ## E.4 Revised Final Project Timeline
#
# Final project topic: sea level rise / coastal environmental science focus.
#
# ### Revised timeline
#
# | Time period | Task |
# |---|---|
# | This week | Finish organizing research sources and review instructor feedback. |
# | Next few days | Refine the project focus, especially the connection between sea level rise, subsidence, and coastal impacts. |
# | Next week | Draft or revise the main sections of the project and identify any missing figures/tables. |
# | Following week | Edit for scientific writing, improve organization, and check citations. |
# | Final stage | Prepare final submission materials and make sure all required pieces are included. |
#
# ## Notes / Linux and HPC Cheat Sheet
#
# ### Commands learned
#
# ```bash
# pwd
# ```
# Shows the current working directory.
#
# ```bash
# ls
# ```
# Lists files and folders in the current directory.
#
# ```bash
# cd folder_name
# ```
# Moves into a folder.
#
# ```bash
# scp source target
# ```
# Securely copies files between a local computer and a remote system such as LSU Mike HPC.
#
# ### Example: local computer to HPC
#
# ```bash
# scp Lab11.2_F24_linux.ipynb your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/
# ```
#
# ### Example: HPC back to local computer
#
# ```bash
# scp your_lsu_username@mike.hpc.lsu.edu:/home/your_lsu_username/Lab11.2_F24_linux.ipynb ~/Downloads/
# ```
#
# ### Key concept
#
# `scp` depends on where the command is run. The source path must be visible from the terminal where the command is executed.
