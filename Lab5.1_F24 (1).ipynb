# %% [markdown]
# Name

# %% [markdown]
# Labpartner(s)

# %%
# import statements go here

# %% [markdown]
# # Class 5.1

# %% [markdown]
# # Warmups 5.1

# %% [markdown]
# **W.1** Go through 1.4.1.2 Creating Arrays in the scipy lecture notes, including the exercises. http://scipy-lectures.org/intro/numpy/array_object.html#id2

# %%
def greet():
    print("Hello, welcome to Lab 5.1!")

greet()
def greet_name(name):
    print("Hello,", name)

greet_name("Aidan")

def square_number(x):
    return x**2

result = square_number(5)
print(result)

def add_numbers(a, b):
    return a + b

print(add_numbers(3, 7))

def power(base, exponent=2):
    return base**exponent

print(power(4))
print(power(4, 3))

# %% [markdown]
# # Lecture 5.1

# %% [markdown]
# ### Agenda:
#
# - Programming questions
# - Examples of for loops

# %% [markdown]
# # Lab 5.1

# %% [markdown]
# **E.1** Complete Lab 4.2 if you haven't allready

# %% [markdown]
# **E.1** Complete Lab 4.2 if you haven't allready

# %% [markdown]
# **E.2** Complete intermediate python chapter 5: Case study on hacker statistics
# ![image.png](attachment:4fb65059-de3c-45d0-9ed6-90d4b2590109.png)

# %% [markdown]
# **E.3** Make notes for yourself on progamming tecniques and commands you learned in the datacamp chapter above, including examples, comments and explainitory text. You can do this here or in a separate notebook that you link to here. Basically, you are making a cheat sheet for yourself.

# %%
def even_or_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

print(even_or_odd(7))

def max_of_three(a, b, c):
    return max(a, b, c)

print(max_of_three(3, 8, 5))

def factorial(n):
    result = 1
    for i in range(1, n+1):
        result *= i
    return result

print(factorial(5))
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

print(is_prime(7))

def count_vowels(string):
    vowels = "aeiouAEIOU"
    count = 0
    for char in string:
        if char in vowels:
            count += 1
    return count

print(count_vowels("Aiden Heath London"))
# Out:
# Odd
# 8
# 120
# True
# 7

# %% [markdown]
# ### Congratulations! অভিনন্দন 恭喜 ¡Felicidades! You finished Intermediate Python!
